# %% [markdown]
# PEWARISAN (INHERITANCE) DALAM PYTHON

# %% [markdown]
# 1. Inheritance Dasar

# %%
# kelas Induk
class Kendaraan:
    def __init__(self, merk) :
        self.merk = merk
    def mulai_mesin(self):
        print(f"Mesin kendaraan {self.merek} dinyalakan")

# Kelas Anak (mewarisi dari Kendaraan)
class Mobil (Kendaraan):
    def __init__(self, merk, warna) :
        # Memanggil __init__ kelas induk ( akan dibahas di Praktikum 2)
        self.merk = merk 
        self.warna = warna # Atribut khusus Mobil

    def info_mobil(self):
        print(f"Ini adalah mobil {self.merk} berwarna {self.warnaa}.")

# --- Kode Utama ---
if __name__ == "__main__":
        mobil_tesla = Mobil("Tesla Model S", "Merah")

        # Memanggil metode dari kelas anak
        mobil_tesla.info_mobil()

        # Memanggil metode yang diwarisi dari kelas induk
        mobil_tesla.mulai_mesin()

        # Mengakses atribut yang diwarisi (dan di-set di anak)
        print(f"Merk mobil: {mobil_tesla.merk}")

# %% [markdown]
# 2. Menggunakan super() dalam konstruktor
