# %% [markdown]
# KONSTRUKTOR, DESTRUKTOR, DAN ENKAPSULASI

# %% [markdown]
# 01. Enkapsulasi pada kelas Bank Account

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.__owner = owner
        self.__balance = balance
    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"{amount} telah ditambahkan ke akun {self._owner}.")
        else:
            print("Jumlah deposit harus lebih dari 0.")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.__balance -= amount
            print(f"{amount} telah ditarik dari akun {self.__owner}")
        else: 
            print("Saldo tidak Mencukupi.")
    def get_balance(self):
        return self._balance

# Contoh Penggunaan
if __name__ == "__main__":
# Membuat objek BankAccount dengan owner-"Alice" dan balance awal
    alice_account = BankAccount(owner="Alice", balance=1000)

    #deposit 
    alice_account.deposit(500)      #berhasil
    alice_account.deposit(-100)    #gagal

    #withdraw
    alice_account.withdraw(300)     #berhasil
    alice_account.withdraw(2000)    #gagal
        
    # Mendapatkan info
    current_balance = Alice_account.get_balance()
    print(f"Saldo terakhir di akun {alice_account.__BankAccount__owner}: {current_balance}") 
    
    #  Mencoba  mengakses  atribut  'private'  langsung  (tidak direkomendasikan) 
     # alice_account.__balance  # Akan error 
          #  Karena  Python  “mangling”  nama  atribut  __balance  menjadi _BankAccount__balance 
     # Ini adalah salah satu mekanisme enkapsulasi sederhana di Python
    # alice_account.__balance # Akan error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 27
#      23 # Membuat objek BankAccount dengan owner-"Alice" dan balance awal
#      24     alice_account = BankAccount(owner="Alice", balance=1000)
#      25
#      26     #deposit
# ---> 27     alice_account.deposit(500)      #berhasil
#      28     alice_account.deposit(-100)    #gagal
#      29
#      30     #withdraw
#
# Cell In[6], line 7, in BankAccount.deposit(self, amount)
#       5     def deposit(self, amount):
#       6         if amount > 0:
# ----> 7             self._balance += amount
#       8             print(f"{amount} telah ditambahkan ke akun {self._owner}.")
#       9         else:
#      10             print("Jumlah deposit harus lebih dari 0.")
#
# AttributeError: 'BankAccount' object has no attribute '_balance'
